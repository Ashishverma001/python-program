# %%
import os 
import requests
import datetime 
import pandas as pd 
from bs4 import BeautifulSoup


def get_soup(url):
    r = requests.get(url)
    if r.status_code == 200:
        return BeautifulSoup(r.text)
    return None

# %%
url ='https://www.flipkart.com/search?q=tv+smart+tv&sid=ckf%2Cczl&as=on&as-show=on&otracker=AS_QueryStore_OrganicAutoSuggest_1_2_na_na_na&otracker1=AS_QueryStore_OrganicAutoSuggest_1_2_na_na_na&as-pos=1&as-type=RECENT&suggestionId=tv+smart+tv%7CTelevisions&requestId=21099032-64a3-47c5-972c-b73458efea78&as-backfill=on'
soup = get_soup(url)

# %%
target = soup.find('div', class_ ='_1YokD2 _3Mn1Gg')
if target is not None:
    print('target found')
# Out:
# target found

# %%
target
# Out:
# <div class="_1YokD2 _3Mn1Gg" style="flex-grow:1;overflow:auto"><div class="_1YokD2 _2GoDe3 col-12-12" style="background-color:#ffffff;align-items:flex-end"><div class="_1AtVbE" style="flex-grow:1;overflow:auto"><div class="W_R1IA"><div class="_1MR4o5"><div class="_3GIHBu"><a class="_2whKao" href="/">Home</a><svg class="_39X-Og" height="27" viewBox="0 0 16 27" width="16" xmlns="http://www.w3.org/2000/svg"><path class="DpXnhQ" d="M16 23.207L6.11 13.161 16 3.093 12.955 0 0 13.161l12.955 13.161z" fill="#fff"></path></svg></div><div class="_3GIHBu"><a class="_2whKao" href="/home-entertainment/pr?sid=ckf&amp;marketplace=FLIPKART">Home Entertainment</a><svg class="_39X-Og" height="27" viewBox="0 0 16 27" width="16" xmlns="http://www.w3.org/2000/svg"><path class="DpXnhQ" d="M16 23.207L6.11 13.161 16 3.093 12.955 0 0 13.161l12.955 13.161z" fill="#fff"></path></svg></div><div class="_3GIHBu"><a class="_2whKao" href="/televisions/pr?sid=ckf,czl&amp;marketplace=FLIPKART">Televisions</a><svg clas
# ...

# %%
items = target.find_all("div", class_ ='_1AtVbE col-12-12')
print(f'found {len(items)} items')
# Out:
# found 26 items

# %%
for item in items:
    title = item.find('div',class_ ='_1AtVbE col-12-12')
    sell_price = item.find('div',class_ ='dyC4hf')
    orig_price = item.find('div',class_ = '_30jeq3 _16Jk6d')
    rating = item.find('div',class_ = '_3LWZlK')
    num_ratings = item.find('span', class_ ='_2_R_DZ')
    if title:
        print(title.text.strip())
    if sell_price:
        print(sell_price.text.strip())
    if orig_price:
        print(orig_price.text.strip())
    if rating:
        print(rating.text.strip())
    if num_ratings:
        print(num_ratings.text.strip())
    print()
# Out:
# 4.3
# 2,19,820 Ratings & 25,037 Reviews
#
# 4.4
# 44,599 Ratings & 3,996 Reviews
#
# 4.4
# 3,11,308 Ratings & 29,604 Reviews
#
# 4.5
# 18,680 Ratings & 5,598 Reviews
#
# 4.2
# 5,556 Ratings & 889 Reviews
#
# 4.3
# 1,24,024 Ratings & 11,420 Reviews
#
# 4.4
# 62,406 Ratings & 5,541 Reviews
#
# 4.6
# 4,157 Ratings & 1,085 Reviews
#
# 4.3
# 30,925 Ratings & 2,718 Reviews
#
# 4.3
# 2,19,820 Ratings & 25,037 Reviews
#
# 4.6
# 4,157 Ratings & 1,085 Reviews
#
# 4.6
# 4,157 Ratings & 1,085 Reviews
#
# 4.4
# 3,11,308 Ratings & 29,604 Reviews
#
# 4.3
# 2,19,820 Ratings & 25,037 Reviews
#
# 4.4
# 80,103 Ratings & 17,145 Reviews
#
# 4.4
# 9,496 Ratings & 1,159 Reviews
#
# 4.5
# 18,680 Ratings & 5,598 Reviews
#
# 4.4
# 34,522 Ratings & 7,722 Reviews
#
# 4.3
# 1,24,024 Ratings & 11,420 Reviews
#
# 4.4
# 1,411 Ratings & 128 Reviews
#
# 4.4
# 34,522 Ratings & 7,722 Reviews
#
# 4.5
# 18,680 Ratings & 5,598 Reviews
#
# 4.4
# 11,243 Ratings & 1,261 Reviews
#
# 4.2
# 8,674 Ratings & 1,178 Reviews
